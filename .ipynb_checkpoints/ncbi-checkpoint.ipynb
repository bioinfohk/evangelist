# %%
import pandas as pd

# %%
df = pd.read_csv("species_NCBI.csv")

# %%
links = df[['GenBank FTP']].values
names = df[['#Organism Name']].values

# %%
len(names)
# Out:
# 5

# %%
link = str(links[0][0])

# %%
link
# Out:
# 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/004/010/195/GCA_004010195.1_ASM401019v1'

# %%
from ftplib import FTP
import os, gzip

files = {}
paths = {}

def files_callback(name):
    files_array.append(name)

for index in range(len(links)):
    link = links[index][0]
    parts = link.split('/', maxsplit=3)
    
    next_path = (parts[3].split('/')[-1] + '_assembly_structure/') + 'Primary_Assembly/assembled_chromosomes/FASTA/'
    ftp = FTP(parts[2])
    ftp.login()
    ftp.cwd(parts[3] + '/' + next_path)
    paths[names[index][0]] = parts[3] + '/' + next_path
    #ftp.cwd('genomes/all/GCA/902/167/405/GCA_902167405.1_gadMor3.0/GCA_902167405.1_gadMor3.0_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/')
    files_array = []
    ftp.retrlines('NLST', callback = files_callback)
    files[names[index][0]] = files_array
    ftp.close()
    
for name, path in paths.items():
    server = 'ftp.ncbi.nlm.nih.gov'
    ftp = FTP(server)
    ftp.login()
    ftp.cwd(path)
    os.mkdir(name)
    os.mkdir(name + '/' + 'dna_sm')
    for filename in files[name]:
        print('download file: ' + filename)
        file_path = os.path.join(name, 'dna_sm', filename)
        fasta_path = os.path.join(name, 'dna_sm', filename[0:-3])
        with open(file_path, 'wb') as file:
            ftp.retrbinary('RETR ' + filename, file.write, 102400)
        handle = gzip.open(file_path)
        with open(fasta_path, 'wb') as out:
            for line in handle:
                out.write(line)
    ftp.close()
# Out:
# download file: chr1.fna.gz
# download file: chr10.fna.gz
# download file: chr11.fna.gz
# download file: chr12.fna.gz
# download file: chr13.fna.gz
# download file: chr14.fna.gz
# download file: chr15.fna.gz
# download file: chr16.fna.gz
# download file: chr17.fna.gz
# download file: chr18.fna.gz
# download file: chr19.fna.gz
# download file: chr2.fna.gz
# download file: chr20.fna.gz
# download file: chr21.fna.gz
# download file: chr22.fna.gz
# download file: chr23.fna.gz
# download file: chr24.fna.gz
# download file: chr25.fna.gz
# download file: chr26.fna.gz
# download file: chr27.fna.gz
# download file: chr28.fna.gz
# download file: chr29.fna.gz
# download file: chr3.fna.gz
# download file: chr30.fna.gz
# download file: chr31.fna.gz
# download file: chr32.fna.gz
# download file: chr33.fna.gz
# download file: chr34.fna.gz
# download file: chr35.fna.gz
# download file: chr36.fna.gz
# download file: chr37.fna.gz
# download file: chr38.fna.gz
# download file: chr39.fna.gz
# download file: chr4.fna.gz
# download file: chr40.fna.gz
# download file: chr41.fna.gz
# download file: chr42.fna.gz
# download file: chr43.fna.gz
# download file: chr44.fna.gz
# download file: chr45.fna.gz
# download file: chr46.fna.gz
# download file: chr47.fna.gz
# download file: chr48.fna.gz
# download file: chr49.fna.gz
# download file: chr5.fna.gz
# download file: chr50.fna.gz
# download file: chr51.fna.gz
# download file: chr6.fna.gz
# download file: chr7.fna.gz
# download file: chr8.fna.gz
# download file: chr9.fna.gz
# download file: chr1.fna.gz
# download file: chr10.fna.gz
# download file: chr11.fna.gz
# download file: chr12.fna.gz
# download file: chr13.fna.gz
# download file: chr14.fna.gz
# download file: chr15.fna.gz
# download file: chr16.fna.gz
# download file: chr17.fna.gz
# download file: chr18.fna.gz
# download file: chr19.fna.gz
# download file: chr2.fna.gz
# download file: chr20.fna.gz
# download file: chr21.fna.gz
# download file: chr22.fna.gz
# download file: chr23.fna.gz
# download file: chr24.fna.gz
# download file: chr25.fna.gz
# download file: chr26.fna.gz
# download file: chr27.fna.gz
# download file: chr28.fna.gz
# download file: chr29.fna.gz
# download file: chr3.fna.gz
# download file: chr30.fna.gz
# download file: chr31.fna.gz
# download file: chr32.fna.gz
# download file: chr33.fna.gz
# download file: chr34.fna.gz
# download file: chr35.fna.gz
# download file: chr36.fna.gz
# download file: chr37.fna.gz
# download file: chr38.fna.gz
# download file: chr39.fna.gz
# download file: chr4.fna.gz
# download file: chr40.fna.gz
# download file: chr41.fna.gz
# download file: chr42.fna.gz
# download file: chr43.fna.gz
# download file: chr44.fna.gz
# download file: chr45.fna.gz
# download file: chr46.fna.gz
# download file: chr5.fna.gz
# download file: chr6.fna.gz
# download file: chr7.fna.gz
# download file: chr8.fna.gz
# download file: chr9.fna.gz
# download file: chr1.fna.gz
# download file: chr10.fna.gz
# download file: chr11.fna.gz
# download file: chr12.fna.gz
# download file: chr13.fna.gz
# download file: chr14.fna.gz
# download file: chr15.fna.gz
# download file: chr16.fna.gz
# download file: chr17.fna.gz
# download file: chr18.fna.gz
# download file: chr19.fna.gz
# download file: chr2.fna.gz
# download file: chr20.fna.gz
# download file: chr21.fna.gz
# download file: chr22.fna.gz
# download file: chr23.fna.gz
# download file: chr24.fna.gz
# download file: chr25.fna.gz
# download file: chr26.fna.gz
# download file: chr27.fna.gz
# download file: chr28.fna.gz
# download file: chr29.fna.gz
# download file: chr3.fna.gz
# download file: chr30.fna.gz
# download file: chr31.fna.gz
# download file: chr32.fna.gz
# download file: chr33.fna.gz
# download file: chr34.fna.gz
# download file: chr35.fna.gz
# download file: chr36.fna.gz
# download file: chr37.fna.gz
# download file: chr38.fna.gz
# download file: chr39.fna.gz
# download file: chr4.fna.gz
# download file: chr40.fna.gz
# download file: chr41.fna.gz
# download file: chr42.fna.gz
# download file: chr43.fna.gz
# download file: chr44.fna.gz
# download file: chr45.fna.gz
# download file: chr46.fna.gz
# download file: chr47.fna.gz
# download file: chr48.fna.gz
# download file: chr49.fna.gz
# download file: chr5.fna.gz
# download file: chr6.fna.gz
# download file: chr7.fna.gz
# download file: chr8.fna.gz
# download file: chr9.fna.gz
# download file: chr1.fna.gz
# download file: chr10.fna.gz
# download file: chr11.fna.gz
# download file: chr12.fna.gz
# download file: chr13.fna.gz
# download file: chr14.fna.gz
# download file: chr15.fna.gz
# download file: chr16.fna.gz
# download file: chr17.fna.gz
# download file: chr18.fna.gz
# download file: chr19.fna.gz
# download file: chr2.fna.gz
# download file: chr20.fna.gz
# download file: chr21.fna.gz
# download file: chr22.fna.gz
# download file: chr23.fna.gz
# download file: chr24.fna.gz
# download file: chr25.fna.gz
# download file: chr26.fna.gz
# download file: chr27.fna.gz
# download file: chr28.fna.gz
# download file: chr29.fna.gz
# download file: chr3.fna.gz
# download file: chr30.fna.gz
# download file: chr31.fna.gz
# download file: chr32.fna.gz
# download file: chr33.fna.gz
# download file: chr34.fna.gz
# download file: chr35.fna.gz
# download file: chr36.fna.gz
# download file: chr37.fna.gz
# download file: chr38.fna.gz
# download file: chr39.fna.gz
# download file: chr4.fna.gz
# download file: chr40.fna.gz
# download file: chr41.fna.gz
# download file: chr42.fna.gz
# download file: chr43.fna.gz
# download file: chr44.fna.gz
# download file: chr45.fna.gz
# download file: chr46.fna.gz
# download file: chr47.fna.gz
# download file: chr48.fna.gz
# download file: chr49.fna.gz
# download file: chr5.fna.gz
# download file: chr50.fna.gz
# download file: chr51.fna.gz
# download file: chr52.fna.gz
# download file: chr53.fna.gz
# download file: chr54.fna.gz
# download file: chr55.fna.gz
# download file: chr56.fna.gz
# download file: chr57.fna.gz
# download file: chr58.fna.gz
# download file: chr59.fna.gz
# download file: chr6.fna.gz
# download file: chr60.fna.gz
# download file: chr7.fna.gz
# download file: chr8.fna.gz
# download file: chr9.fna.gz
# download file: chr1.fna.gz
# download file: chr10.fna.gz
# download file: chr11.fna.gz
# download file: chr12.fna.gz
# download file: chr13.fna.gz
# download file: chr14.fna.gz
# download file: chr15.fna.gz
# download file: chr16.fna.gz
# download file: chr17.fna.gz
# download file: chr18.fna.gz
# download file: chr19.fna.gz
# download file: chr2.fna.gz
# download file: chr20.fna.gz
# download file: chr21.fna.gz
# download file: chr22.fna.gz
# download file: chr23.fna.gz
# download file: chr3.fna.gz
# download file: chr4.fna.gz
# download file: chr5.fna.gz
# download file: chr6.fna.gz
# download file: chr7.fna.gz
# download file: chr8.fna.gz
# download file: chr9.fna.gz

# %%
ftp.cwd('genomes/all/GCA/902/167/405/GCA_902167405.1_gadMor3.0/GCA_902167405.1_gadMor3.0_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/')
# Out:
# '250 CWD command successful'

# %%
paths
# Out:
# {'Chiloscyllium plagiosum': 'genomes/all/GCA/004/010/195/GCA_004010195.1_ASM401019v1/GCA_004010195.1_ASM401019v1_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/',
#  'Pristis pectinata': 'genomes/all/GCA/009/764/475/GCA_009764475.1_sPriPec2.pri/GCA_009764475.1_sPriPec2.pri_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/',
#  'Amblyraja radiata': 'genomes/all/GCA/010/909/765/GCA_010909765.1_sAmbRad1.pri/GCA_010909765.1_sAmbRad1.pri_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/',
#  'Acipenser ruthenus': 'genomes/all/GCA/010/645/085/GCA_010645085.1_ASM1064508v1/GCA_010645085.1_ASM1064508v1_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/',
#  'Gadus morhua': 'genomes/all/GCA/902/167/405/GCA_902167405.1_gadMor3.0/GCA_902167405.1_gadMor3.0_assembly_structure/Primary_Assembly/assembled_chromosomes/FASTA/'}

# %%
from dna_puller.sliding_parser import SlidingParser
import os, json

names = [ 'Rhinolophus_ferrumequinum'
]

for index in range(len(names)):
    name = names[index]
    path = name + "/dna_sm"
    data = {'dna_sm': {}}
    
    files = os.listdir(path)
    fasta_files = []
    
    for file in files:
        if file[-3:] == '.fa':
            fasta_files.append(file)
    
    for file in fasta_files:
        parser = SlidingParser(1000)
        data['dna_sm'].update(parser.parse_file(path + "/" + file))
    
    json_path = os.path.join('jsons' , name + '.json')
    print('creating ' + json_path)
    with open(json_path, 'w') as fp:
         json.dump(data, fp)
# Out:
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.1.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.10.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.11.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.12.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.13.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.14.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.15.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.16.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.17.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.18.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.19.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.2.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.20.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.21.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.22.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.23.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.24.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.25.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.26.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.27.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.28.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.3.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.4.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.5.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.6.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.7.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.8.fa
# Analysing: Rhinolophus_ferrumequinum/dna_sm/Rhinolophus_ferrumequinum.mRhiFer1_v1.p.dna_sm.primary_assembly.9.fa
# creating jsons/Rhinolophus_ferrumequinum.json

# %%
json_files = ['Pristis_pectinata.json',
'Chiloscyllium_plagiosum.json',
#'Myotis_lucifugus.json',
#'Pteropus_vampyrus.json',
#'Rhinolophus_ferrumequinum.json'
]

# %%
import csv, os, json

file_counts = {}


for file in json_files:
    name = file[:-5]
    data = {}
    if not os.path.exists('csv/' + name):
        os.mkdir('csv/' + name)
    with open('jsons/' + file) as f:
        data = json.load(f)
    file_counts[file] = {'sm': [], 'all': []}
    for lg, values in data.items():
        if lg[:2] == 'LR' or lg[:2] == 'CM':
            with open('csv/' + name + '/' + lg + '.csv', 'w', newline='') as csvfile:
                #print(lg)
                csvwriter = csv.writer(csvfile, delimiter=' ',
                                        quotechar='|', quoting=csv.QUOTE_MINIMAL)

                for index, value in values.items():
                    gc_count = value['G'] + value['C'] + value['S'] + value['g'] + value['c'] + value['s']
                    all_count = value['all'] - value['N'] - value['n']

                    big_percent = 0 
                    if value['all_big'] > 0:
                        big_percent = value['all_big'] / float(value['all'])
                        if big_percent < 1:
                            file_counts[file]['sm'].append(big_percent)
                        file_counts[file]['all'].append(big_percent)

                    if all_count > 0:
                        gc_val = gc_count/all_count

                    csvwriter.writerow([index, gc_val, big_percent])

# %%
len(file_counts['gadus_morhua.json']['sm'])
# Out:
# 331

# %%
import os, subprocess

def file_len(fname):
    p = subprocess.Popen(['wc', '-l', fname], stdout=subprocess.PIPE, 
                                              stderr=subprocess.PIPE)
    result, err = p.communicate()
    if p.returncode != 0:
        raise IOError(err)
    return int(result.strip().split()[0])

csv_folders = 'csv'

#folders = os.listdir(csv_folders)
folders = ['Oryzias_latipes',
'Esox_lucius',
'Betta_splendens',
'Lepisosteus_oculatus',
'Danio_rerio',
'Erpetoichthys_calabaricus',
'Salmo_salar',
'Takifugu_rubripes',
#'Acipenser_ruthenus'
'Ciona_intestinalis',
'Felis_catus',
'Gorilla_gorilla'
]

folders = ['Pristis_pectinata',
'Chiloscyllium_plagiosum']

species_folders = []

for folder in folders:
    if folder[0] != '.':
        species_folders.append(folder)

files = {}
biggest_files = {}
sorted_files = {}
for folder in species_folders:
    biggest_files[folder] = 0
    sorted_files[folder] = {}
    csv_files = []
    for file in os.listdir(csv_folders + '/' + folder):
        if file[-4:] == '.csv':
            csv_files.append(file)
            
            len_f =  file_len(csv_folders + '/' + folder + '/' + file)
            sorted_files[folder][file] = len_f
            if biggest_files[folder] < len_f * 1000:
                biggest_files[folder] = len_f * 1000
    files[folder] = csv_files 
    sorted_files[folder] = sorted(sorted_files[folder], key = sorted_files[folder].get, reverse=True)

# %%
from gnuplot_generator.gnuplot_generator import GnuplotGenerator

def create_plot(fname):
    p = subprocess.Popen(['gnuplot', '-p', fname], stdout=subprocess.PIPE, 
                                                   stderr=subprocess.PIPE)
    result, err = p.communicate()
    if p.returncode != 0:
        raise IOError(err)       
postfix = 'normal'    
        
for folder in species_folders:
    range_plot = '[0:' + str(biggest_files[folder]) + ']'
    gen = GnuplotGenerator(folder, range_plot)
    gen.add_palette("( 0 'green', 50 'orange', 100 'red')")
    gen.set_term('png', 'plots_' + postfix + '/' + folder + '_' + postfix + '.png', 10000, 0.1)
    
    if not os.path.exists('plots_' + postfix):
        os.makedirs('plots_' + postfix)
    
    for file in sorted_files[folder]:
        gen.add_plot(csv_folders + '/' + folder + '/' + file, '1:2:3', file[:-4])
    
    with open(csv_folders + '/' + folder + '/' + folder + '_' + postfix + '.gnu', 'w') as gnu_file:
        lines = gen.prepare_definition()
        for line in lines:
            gnu_file.write(line + '\n')
    
    create_plot(csv_folders + '/' + folder + '/' + folder + '_' + postfix + '.gnu')
